# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
bike = pd.read_csv('Bike-Sharing-Dataset\hour.csv')

# %%
bike.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>instant</th>
#       <th>dteday</th>
#       <th>season</th>
#       <th>yr</th>
#       <th>mnth</th>
#       <th>hr</th>
#       <th>holiday</th>
#       <th>weekday</th>
#       <th>workingday</th>
#       <th>weathersit</th>
#       <th>temp</th>
#       <th>atemp</th>
#       <th>hum</th>
#       <th>windspeed</th>
#       <th>casual</th>
#       <th>registered</th>
#       <th>cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2011-01-01</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>6</td>
# ...

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
# instant       17379 non-null int64
# dteday        17379 non-null object
# season        17379 non-null int64
# yr            17379 non-null int64
# mnth          17379 non-null int64
# hr            17379 non-null int64
# holiday       17379 non-null int64
# weekday       17379 non-null int64
# workingday    17379 non-null int64
# weathersit    17379 non-null int64
# temp          17379 non-null float64
# atemp         17379 non-null float64
# hum           17379 non-null float64
# windspeed     17379 non-null float64
# casual        17379 non-null int64
# registered    17379 non-null int64
# cnt           17379 non-null int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.2+ MB

# %%
bike.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>instant</th>
#       <th>season</th>
#       <th>yr</th>
#       <th>mnth</th>
#       <th>hr</th>
#       <th>holiday</th>
#       <th>weekday</th>
#       <th>workingday</th>
#       <th>weathersit</th>
#       <th>temp</th>
#       <th>atemp</th>
#       <th>hum</th>
#       <th>windspeed</th>
#       <th>casual</th>
#       <th>registered</th>
#       <th>cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>17379.0000</td>
#       <td>17379.000000</td>
#       <td>17379.000000</td>
#       <td>17379.000000</td>
#       <td>17379.000000</td>
#       <td>17379.000000</td>
# ...

# %%
bike.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
sns.heatmap(bike.corr())

# %%
bike.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
sns.distplot(bike['cnt'])

# %%
X = bike[['instant', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
       'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed']]
Y = bike['cnt']

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(lm.intercept_)
# Out:
# -22.4548253791

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Coefficient</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>instant</th>
#       <td>-0.003237</td>
#     </tr>
#     <tr>
#       <th>season</th>
#       <td>21.921890</td>
#     </tr>
#     <tr>
#       <th>yr</th>
#       <td>111.759894</td>
#     </tr>
#     <tr>
#       <th>mnth</th>
#       <td>2.130287</td>
#     </tr>
#     <tr>
#       <th>hr</th>
#       <td>7.563226</td>
#     </tr>
#     <tr>
#       <th>holiday</th>
#       <td>-25.183782</td>
#     </tr>
#     <tr>
#       <th>weekday</th>
#       <td>1.529583</td>
#     </tr>
#     <tr>
#       <th>workingday</th>
#       <td>4.354963</td>
# ...

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(Y_test, predictions)

# %%
sns.distplot((Y_test-predictions), bins=50)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
print('MSE:', metrics.mean_squared_error(Y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
# Out:
# MAE: 105.213896576
# MSE: 19413.5473701
# RMSE: 139.332506509

# %%
plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.5)
plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40)
plt.title('Training in blue, test in green')
plt.ylabel('Residuals')

# %%
plt.scatter(X_train['atemp'], Y_train)
plt.ylabel('counts')
plt.xlabel('temperature')

# %%
X_train
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>instant</th>
#       <th>season</th>
#       <th>yr</th>
#       <th>mnth</th>
#       <th>hr</th>
#       <th>holiday</th>
#       <th>weekday</th>
#       <th>workingday</th>
#       <th>weathersit</th>
#       <th>temp</th>
#       <th>atemp</th>
#       <th>hum</th>
#       <th>windspeed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5749</th>
#       <td>5750</td>
#       <td>3</td>
#       <td>0</td>
#       <td>9</td>
#       <td>0</td>
#       <td>0</td>
#       <td>5</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0.64</td>
#       <td>0.6061</td>
#       <td>0.65</td>
#       <td>0.1940</td>
# ...

# %%
predictions = lm.predict(X_test)
plt.scatter(Y_test, predictions)
plt.xlabel('Y test')
plt.ylabel('Predicted Y')

# %%
X = bike[['instant', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
       'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed']]
Y = bike['cnt']

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.33, random_state=42)
lm = LinearRegression()
lm.fit(X_train, Y_train)
predictions = lm.predict(X_test)
print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
print('MSE:', metrics.mean_squared_error(Y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
# Out:
# MAE: 105.514638245
# MSE: 19479.1212314
# RMSE: 139.567622432

# %%
X = bike[['yr', 'mnth', 'hr', 'holiday', 'weekday',
       'workingday', 'weathersit', 'temp', 'atemp', 'windspeed']]
Y = bike['cnt']

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.33, random_state=42)
lm = LinearRegression()
lm.fit(X_train, Y_train)
predictions = lm.predict(X_test)
print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
print('MSE:', metrics.mean_squared_error(Y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
# Out:
# MAE: 108.425516245
# MSE: 20364.2414776
# RMSE: 142.7033338

# %%
X = bike[['instant', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed']]
Y = bike['cnt']
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.33, random_state=42)
lm = LinearRegression()
lm.fit(X_train, Y_train)
predictions = lm.predict(X_test)
print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
print('MSE:', metrics.mean_squared_error(Y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.5)
plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40)
plt.title('Training in blue, test in green')
plt.ylabel('Residuals')
# Out:
# MAE: 105.388458153
# MSE: 19480.7704001
# RMSE: 139.573530442

# %%
X = bike[[ 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed']]
Y = bike['cnt']
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.33, random_state=42)
lm = LinearRegression()
lm.fit(X_train, Y_train)
predictions = lm.predict(X_test)
print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
print('MSE:', metrics.mean_squared_error(Y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.5)
plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40)
plt.title('Training in blue, test in green')
plt.ylabel('Residuals')
# Out:
# MAE: 105.404779904
# MSE: 19483.2066365
# RMSE: 139.582257599

# %%
X = bike[[ 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed']]
Y = bike['cnt']
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.33, random_state=42)
lm = LinearRegression()
lm.fit(X_train, Y_train)
predictions = lm.predict(X_test)
print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
print('MSE:', metrics.mean_squared_error(Y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.5)
plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40)
plt.title('Training in blue, test in green')
plt.ylabel('Residuals')
# Out:
# MAE: 105.404779904
# MSE: 19483.2066365
# RMSE: 139.582257599

# %%
plt.scatter(bike['season'], bike['cnt'])

# %%
plt.scatter(bike['yr'], bike['cnt'])

# %%
plt.scatter(bike['mnth'], bike['cnt'])

# %%
plt.scatter(bike['hr'], bike['cnt'])

# %%
plt.scatter(bike['weekday'], bike['cnt'])

# %%
plt.scatter(bike['weathersit'], bike['cnt'])

# %%
plt.scatter(bike['temp'], bike['cnt'])

# %%
plt.scatter(bike['atemp'], bike['cnt'])

# %%
plt.scatter(bike['hum'], bike['cnt'])

# %%
plt.scatter(bike['windspeed'], bike['cnt'])

# %%
X = bike[[ 'temp', 'atemp', 'hum','windspeed', 'weekday']]
Y = bike['cnt']
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.33, random_state=42)
lm = LinearRegression()
lm.fit(X_train, Y_train)
predictions = lm.predict(X_test)
print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
print('MSE:', metrics.mean_squared_error(Y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.5)
plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40)
plt.title('Training in blue, test in green')
plt.ylabel('Residuals')
# Out:
# MAE: 116.029928519
# MSE: 23635.4671215
# RMSE: 153.738307267

# %%
X = bike[['mnth']]
Y = bike['cnt']
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.33, random_state=42)
lm = LinearRegression()
lm.fit(X_train, Y_train)
predictions = lm.predict(X_test)
print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
print('MSE:', metrics.mean_squared_error(Y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.5)
plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40)
plt.title('Training in blue, test in green')
plt.ylabel('Residuals')
# Out:
# MAE: 140.044737785
# MSE: 31531.2914879
# RMSE: 177.570525392

# %%
bike
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>instant</th>
#       <th>dteday</th>
#       <th>season</th>
#       <th>yr</th>
#       <th>mnth</th>
#       <th>hr</th>
#       <th>holiday</th>
#       <th>weekday</th>
#       <th>workingday</th>
#       <th>weathersit</th>
#       <th>temp</th>
#       <th>atemp</th>
#       <th>hum</th>
#       <th>windspeed</th>
#       <th>casual</th>
#       <th>registered</th>
#       <th>cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2011-01-01</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>6</td>
# ...

# %%
bike_index = bike.set_index(['workingday','mnth']).sort_index()

# %%
bike_index1 = bike_index.loc[0]
bike_index2 = bike_index.loc[1]

# %%
def plot(bike_index1, xlabel):
    X = bike_index1[['hr', 'holiday', 'weekday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed']]
    Y = bike_index1['cnt']
    from sklearn.model_selection import train_test_split
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.33, random_state=42)
    lm = LinearRegression()
    lm.fit(X_train, Y_train)
    predictions = lm.predict(X_test)
    print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
    print('MSE:', metrics.mean_squared_error(Y_test, predictions))
    print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
    plt.figure(figsize=(12,2.5))
    plt.scatter(lm.predict(X_train), lm.predict(X_train) - Y_train, c='b', s=40, alpha=0.5)
    plt.scatter(lm.predict(X_test), lm.predict(X_test) - Y_test, c='g', s=40)
    plt.title('Training in blue, test in green')
    plt.ylabel('Residuals')
    plt.xlabel(xlabel)

# %%
for i in range(1, 13):
    xlabel = 'month ' + str(i)
    bindex = bike_index2.loc[i]
    plot(bindex, xlabel)
# Out:
# MAE: 61.141371082
# MSE: 7968.04422515
# RMSE: 89.2639021394
# MAE: 85.8182576337
# MSE: 15646.2334359
# RMSE: 125.084904908
# MAE: 95.9356945803
# MSE: 16438.4029321
# RMSE: 128.212335335
# MAE:
#  113.445928251
# MSE: 21503.2169163
# RMSE: 146.63975217
# MAE: 112.140198957
# MSE: 24038.5497809
# RMSE: 155.04370281
# MAE: 120.491358212
# MSE: 27378.4238426
# RMSE: 165.46426757
# MAE: 125.560092301
# MSE: 30766.1649434
# RMSE: 175.402864695
# MAE: 127.494417179
# MSE: 27866.2174986
# RMSE: 166.931774982
# MAE: 127.05564911
# MSE: 28833.3648984
# RMSE: 169.803901305
# MAE: 133.805523325
# MSE: 32847.5257355
# RMSE: 181.238863756
# MAE: 103.065430103
# MSE: 17510.3513993
# RMSE: 132.326684381
# MAE: 96.5029008815
# MSE: 18058.0810189
# RMSE: 134.380359498

# %%
bike_index2 = bike_index.i
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>instant</th>
#       <th>dteday</th>
#       <th>season</th>
#       <th>yr</th>
#       <th>hr</th>
#       <th>holiday</th>
#       <th>weekday</th>
#       <th>workingday</th>
#       <th>weathersit</th>
#       <th>temp</th>
#       <th>atemp</th>
#       <th>hum</th>
#       <th>windspeed</th>
#       <th>casual</th>
#       <th>registered</th>
#       <th>cnt</th>
#     </tr>
#     <tr>
#       <th>mnth</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...
